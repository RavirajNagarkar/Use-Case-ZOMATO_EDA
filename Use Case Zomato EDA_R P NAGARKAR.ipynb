# %% [markdown]
# ## Mr. Raviraj Nagarkar
#
# ##Breakdown of this notebook:
#
# ## Loading the dataset: Load the data and import the libraries.
#
# ##Data Cleaning:
# #Deleting redundant columns.
# #Renaming the columns.
# #Dropping duplicates.
# #Cleaning individual columns.
# #Remove the NaN values from the dataset
#
# ##Some Transformations
# #Regression Analysis
# #Linear Regression
# #Decision Tree Regression
# #Random Forest Regression
#
# ##Data Visualization: Using plots to find relations between the features.
# #Restaurants delivering Online or not
# #Restaurants allowing table booking or not
# #Table booking Rate vs Rate
# #Best Location
#
# ##Relation between Location and Rating
# #Restaurant Type
# #Gaussian Rest type and Rating
#
# ##Types of Services
# #Relation between Type and Rating
# #Cost of Restuarant
# #No. of restaurants in a Location
# #Restaurant type
# #Most famous restaurant chains in Bengaluru

# %% [markdown]
# ## The basic idea is analyzing the Buisness Problem of Zomato to get a fair idea about the factors affecting the establishment of different types of restaurant at different places in Bengaluru, aggregate rating of each restaurant and many more. I have provided the link to download the dataset at the end of this notebook.

# %%
import numpy as np

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
zomato=pd.read_csv('zomato.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_6392/1381820655.py in <module>
# ----> 1 zomato=pd.read_csv('zomato.csv')
#
# ~\Raviraj\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
zomato
# Out:
#                                                      url  \
# 0      https://www.zomato.com/bangalore/jalsa-banasha...
# 1      https://www.zomato.com/bangalore/spice-elephan...
# 2      https://www.zomato.com/SanchurroBangalore?cont...
# 3      https://www.zomato.com/bangalore/addhuri-udupi...
# 4      https://www.zomato.com/bangalore/grand-village...
# ...                                                  ...
# 51712  https://www.zomato.com/bangalore/best-brews-fo...
# 51713  https://www.zomato.com/bangalore/vinod-bar-and...
# 51714  https://www.zomato.com/bangalore/plunge-sherat...
# 51715  https://www.zomato.com/bangalore/chime-sherato...
# 51716  https://www.zomato.com/bangalore/the-nest-the-...
#
#                                                  address  \
# 0      942, 21st Main Road, 2nd Stage, Banashankari, ...
# 1      2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...
# 2      1112, Next to KIMS Medical College, 17th Cross...
# ...

# %%
type(zomato)
# Out:
# pandas.core.frame.DataFrame

# %%
zomato.shape
# Out:
# (51717, 17)

# %%
zomato.head()
# Out:
#                                                  url  \
# 0  https://www.zomato.com/bangalore/jalsa-banasha...
# 1  https://www.zomato.com/bangalore/spice-elephan...
# 2  https://www.zomato.com/SanchurroBangalore?cont...
# 3  https://www.zomato.com/bangalore/addhuri-udupi...
# 4  https://www.zomato.com/bangalore/grand-village...
#
#                                              address                   name  \
# 0  942, 21st Main Road, 2nd Stage, Banashankari, ...                  Jalsa
# 1  2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...         Spice Elephant
# 2  1112, Next to KIMS Medical College, 17th Cross...        San Churro Cafe
# 3  1st Floor, Annakuteera, 3rd Stage, Banashankar...  Addhuri Udupi Bhojana
# 4  10, 3rd Floor, Lakshmi Associates, Gandhi Baza...          Grand Village
#
#   online_order book_table   rate  votes                             phone  \
# 0          Yes        Yes  4.1/5    775    080 42297555\r\n+91 9743772233
# ...

# %%
zomato.tail()
# Out:
#                                                      url  \
# 51712  https://www.zomato.com/bangalore/best-brews-fo...
# 51713  https://www.zomato.com/bangalore/vinod-bar-and...
# 51714  https://www.zomato.com/bangalore/plunge-sherat...
# 51715  https://www.zomato.com/bangalore/chime-sherato...
# 51716  https://www.zomato.com/bangalore/the-nest-the-...
#
#                                                  address  \
# 51712  Four Points by Sheraton Bengaluru, 43/3, White...
# 51713  Number 10, Garudachar Palya, Mahadevapura, Whi...
# 51714  Sheraton Grand Bengaluru Whitefield Hotel & Co...
# 51715  Sheraton Grand Bengaluru Whitefield Hotel & Co...
# 51716  ITPL Main Road, KIADB Export Promotion Industr...
#
#                                                     name online_order  \
# 51712  Best Brews - Four Points by Sheraton Bengaluru...           No
# 51713                           Vinod Bar And Restaurant           No
# ...

# %%
zomato
# Out:
#                                                      url  \
# 0      https://www.zomato.com/bangalore/jalsa-banasha...
# 1      https://www.zomato.com/bangalore/spice-elephan...
# 2      https://www.zomato.com/SanchurroBangalore?cont...
# 3      https://www.zomato.com/bangalore/addhuri-udupi...
# 4      https://www.zomato.com/bangalore/grand-village...
# ...                                                  ...
# 51712  https://www.zomato.com/bangalore/best-brews-fo...
# 51713  https://www.zomato.com/bangalore/vinod-bar-and...
# 51714  https://www.zomato.com/bangalore/plunge-sherat...
# 51715  https://www.zomato.com/bangalore/chime-sherato...
# 51716  https://www.zomato.com/bangalore/the-nest-the-...
#
#                                                  address  \
# 0      942, 21st Main Road, 2nd Stage, Banashankari, ...
# 1      2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...
# 2      1112, Next to KIMS Medical College, 17th Cross...
# ...

# %%
zomato.columns
# Out:
# Index(['url', 'address', 'name', 'online_order', 'book_table', 'rate', 'votes',
#        'phone', 'location', 'rest_type', 'dish_liked', 'cuisines',
#        'approx_cost(for two people)', 'reviews_list', 'menu_item',
#        'listed_in(type)', 'listed_in(city)'],
#       dtype='object')

# %%
zomato.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51717 entries, 0 to 51716
# Data columns (total 17 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   url                          51717 non-null  object
#  1   address                      51717 non-null  object
#  2   name                         51717 non-null  object
#  3   online_order                 51717 non-null  object
#  4   book_table                   51717 non-null  object
#  5   rate                         43942 non-null  object
#  6   votes                        51717 non-null  int64
#  7   phone                        50509 non-null  object
#  8   location                     51696 non-null  object
#  9   rest_type                    51490 non-null  object
#  10  dish_liked                   23639 non-null  object
#  11  cuisines                     51672 non-null  object
#  12  approx_cost(for two people)  51371 non-null  object
# ...

# %%
zomato.isnull().sum()
# Out:
# url                                0
# address                            0
# name                               0
# online_order                       0
# book_table                         0
# rate                            7775
# votes                              0
# phone                           1208
# location                          21
# rest_type                        227
# dish_liked                     28078
# cuisines                          45
# approx_cost(for two people)      346
# reviews_list                       0
# menu_item                          0
# listed_in(type)                    0
# listed_in(city)                    0
# dtype: int64

# %%
zomato
# Out:
#                                                      url  \
# 0      https://www.zomato.com/bangalore/jalsa-banasha...
# 1      https://www.zomato.com/bangalore/spice-elephan...
# 2      https://www.zomato.com/SanchurroBangalore?cont...
# 3      https://www.zomato.com/bangalore/addhuri-udupi...
# 4      https://www.zomato.com/bangalore/grand-village...
# ...                                                  ...
# 51712  https://www.zomato.com/bangalore/best-brews-fo...
# 51713  https://www.zomato.com/bangalore/vinod-bar-and...
# 51714  https://www.zomato.com/bangalore/plunge-sherat...
# 51715  https://www.zomato.com/bangalore/chime-sherato...
# 51716  https://www.zomato.com/bangalore/the-nest-the-...
#
#                                                  address  \
# 0      942, 21st Main Road, 2nd Stage, Banashankari, ...
# 1      2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...
# 2      1112, Next to KIMS Medical College, 17th Cross...
# ...

# %%
zomato.head(10)
# Out:
#                                                  url  \
# 0  https://www.zomato.com/bangalore/jalsa-banasha...
# 1  https://www.zomato.com/bangalore/spice-elephan...
# 2  https://www.zomato.com/SanchurroBangalore?cont...
# 3  https://www.zomato.com/bangalore/addhuri-udupi...
# 4  https://www.zomato.com/bangalore/grand-village...
# 5  https://www.zomato.com/bangalore/timepass-dinn...
# 6  https://www.zomato.com/bangalore/rosewood-inte...
# 7  https://www.zomato.com/bangalore/onesta-banash...
# 8  https://www.zomato.com/bangalore/penthouse-caf...
# 9  https://www.zomato.com/bangalore/smacznego-ban...
#
#                                              address  \
# 0  942, 21st Main Road, 2nd Stage, Banashankari, ...
# 1  2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...
# 2  1112, Next to KIMS Medical College, 17th Cross...
# 3  1st Floor, Annakuteera, 3rd Stage, Banashankar...
# 4  10, 3rd Floor, Lakshmi Associates, Gandhi Baza...
# 5  37, 5-1, 4th Floor, Bosco Court, Gandhi Bazaar...
# ...

# %%
zomato.tail(10)
# Out:
#                                                      url  \
# 51707  https://www.zomato.com/bangalore/m-bar-bengalu...
# 51708  https://www.zomato.com/bangalore/keys-cafe-key...
# 51709  https://www.zomato.com/bangalore/the-farm-hous...
# 51710  https://www.zomato.com/bangalore/topsy-turvey-...
# 51711  https://www.zomato.com/bangalore/bhagini-2-whi...
# 51712  https://www.zomato.com/bangalore/best-brews-fo...
# 51713  https://www.zomato.com/bangalore/vinod-bar-and...
# 51714  https://www.zomato.com/bangalore/plunge-sherat...
# 51715  https://www.zomato.com/bangalore/chime-sherato...
# 51716  https://www.zomato.com/bangalore/the-nest-the-...
#
#                                                  address  \
# 51707  Bengaluru Marriott Hotel, 75, 8th Road, EPIP A...
# 51708  Keys Hotel, 6, 1st Phase Industrial Area, Near...
# 51709  136, SAP Labs India, KIADB Export Promotion In...
# 51710  2E2, 4th Cross Road, Devasandra Industrial Est...
# ...

# %%
zomato.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51717 entries, 0 to 51716
# Data columns (total 17 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   url                          51717 non-null  object
#  1   address                      51717 non-null  object
#  2   name                         51717 non-null  object
#  3   online_order                 51717 non-null  object
#  4   book_table                   51717 non-null  object
#  5   rate                         43942 non-null  object
#  6   votes                        51717 non-null  int64
#  7   phone                        50509 non-null  object
#  8   location                     51696 non-null  object
#  9   rest_type                    51490 non-null  object
#  10  dish_liked                   23639 non-null  object
#  11  cuisines                     51672 non-null  object
#  12  approx_cost(for two people)  51371 non-null  object
# ...

# %%
zomato.describe()
# Out:
#               votes
# count  51717.000000
# mean     283.697527
# std      803.838853
# min        0.000000
# 25%        7.000000
# 50%       41.000000
# 75%      198.000000
# max    16832.000000

# %%
zomato.columns
# Out:
# Index(['url', 'address', 'name', 'online_order', 'book_table', 'rate', 'votes',
#        'phone', 'location', 'rest_type', 'dish_liked', 'cuisines',
#        'approx_cost(for two people)', 'reviews_list', 'menu_item',
#        'listed_in(type)', 'listed_in(city)'],
#       dtype='object')

# %%
zomato1=zomato.drop(['url','dish_liked','phone'],axis=1)

# %%
zomato1.columns
# Out:
# Index(['address', 'name', 'online_order', 'book_table', 'rate', 'votes',
#        'location', 'rest_type', 'cuisines', 'approx_cost(for two people)',
#        'reviews_list', 'menu_item', 'listed_in(type)', 'listed_in(city)'],
#       dtype='object')

# %%
zomato1.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 51712    False
# 51713    False
# 51714    False
# 51715    False
# 51716    False
# Length: 51717, dtype: bool

# %%
zomato1.duplicated().sum()
# Out:
# 43

# %%
zomato1.shape
# Out:
# (51717, 14)

# %%
zomato1.drop_duplicates()
# Out:
#                                                  address  \
# 0      942, 21st Main Road, 2nd Stage, Banashankari, ...
# 1      2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...
# 2      1112, Next to KIMS Medical College, 17th Cross...
# 3      1st Floor, Annakuteera, 3rd Stage, Banashankar...
# 4      10, 3rd Floor, Lakshmi Associates, Gandhi Baza...
# ...                                                  ...
# 51712  Four Points by Sheraton Bengaluru, 43/3, White...
# 51713  Number 10, Garudachar Palya, Mahadevapura, Whi...
# 51714  Sheraton Grand Bengaluru Whitefield Hotel & Co...
# 51715  Sheraton Grand Bengaluru Whitefield Hotel & Co...
# 51716  ITPL Main Road, KIADB Export Promotion Industr...
#
#                                                     name online_order  \
# 0                                                  Jalsa          Yes
# 1                                         Spice Elephant          Yes
# ...

# %%
zomato1.drop_duplicates(inplace=True)

# %%
51717-43
# Out:
# 51674

# %%
zomato1.shape
# Out:
# (51674, 14)

# %%
zomato1.isnull()
# Out:
#        address   name  online_order  book_table   rate  votes  location  \
# 0        False  False         False       False  False  False     False
# 1        False  False         False       False  False  False     False
# 2        False  False         False       False  False  False     False
# 3        False  False         False       False  False  False     False
# 4        False  False         False       False  False  False     False
# ...        ...    ...           ...         ...    ...    ...       ...
# 51712    False  False         False       False  False  False     False
# 51713    False  False         False       False   True  False     False
# 51714    False  False         False       False   True  False     False
# 51715    False  False         False       False  False  False     False
# 51716    False  False         False       False  False  False     False
#
#        rest_type  cuisines  approx_cost(for two people)  reviews_list  \
# ...

# %%
zomato1.isnull().sum()
# Out:
# address                           0
# name                              0
# online_order                      0
# book_table                        0
# rate                           7767
# votes                             0
# location                         21
# rest_type                       227
# cuisines                         45
# approx_cost(for two people)     345
# reviews_list                      0
# menu_item                         0
# listed_in(type)                   0
# listed_in(city)                   0
# dtype: int64

# %%
zomato1.dropna(how='any',inplace=True)

# %%
zomato1.shape
# Out:
# (43499, 14)

# %%
zomato1.isnull().sum
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.sum of        address   name  online_order  book_table   rate  votes  location  \
# 0        False  False         False       False  False  False     False
# 1        False  False         False       False  False  False     False
# 2        False  False         False       False  False  False     False
# 3        False  False         False       False  False  False     False
# 4        False  False         False       False  False  False     False
# ...        ...    ...           ...         ...    ...    ...       ...
# 51709    False  False         False       False  False  False     False
# 51711    False  False         False       False  False  False     False
# 51712    False  False         False       False  False  False     False
# 51715    False  False         False       False  False  False     False
# 51716    False  False         False       False  False  False     False
#
# ...

# %%
zomato1.columns
# Out:
# Index(['address', 'name', 'online_order', 'book_table', 'rate', 'votes',
#        'location', 'rest_type', 'cuisines', 'approx_cost(for two people)',
#        'reviews_list', 'menu_item', 'listed_in(type)', 'listed_in(city)'],
#       dtype='object')

# %%
zomato2=zomato1.rename(columns={'approx_cost(for two people)':'cost','listed_in(type)':'type',
                               'listed_in(city)':'city'})

# %%
zomato2.columns
# Out:
# Index(['address', 'name', 'online_order', 'book_table', 'rate', 'votes',
#        'location', 'rest_type', 'cuisines', 'cost', 'reviews_list',
#        'menu_item', 'type', 'city'],
#       dtype='object')

# %%
zomato2
# Out:
#                                                  address  \
# 0      942, 21st Main Road, 2nd Stage, Banashankari, ...
# 1      2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...
# 2      1112, Next to KIMS Medical College, 17th Cross...
# 3      1st Floor, Annakuteera, 3rd Stage, Banashankar...
# 4      10, 3rd Floor, Lakshmi Associates, Gandhi Baza...
# ...                                                  ...
# 51709  136, SAP Labs India, KIADB Export Promotion In...
# 51711  139/C1, Next To GR Tech Park, Pattandur Agraha...
# 51712  Four Points by Sheraton Bengaluru, 43/3, White...
# 51715  Sheraton Grand Bengaluru Whitefield Hotel & Co...
# 51716  ITPL Main Road, KIADB Export Promotion Industr...
#
#                                                     name online_order  \
# 0                                                  Jalsa          Yes
# 1                                         Spice Elephant          Yes
# ...

# %%
zomato2.columns
# Out:
# Index(['address', 'name', 'online_order', 'book_table', 'rate', 'votes',
#        'location', 'rest_type', 'cuisines', 'cost', 'reviews_list',
#        'menu_item', 'type', 'city'],
#       dtype='object')

# %%
zomato2['cost']
# Out:
# 0          800
# 1          800
# 2          800
# 3          300
# 4          600
#          ...
# 51709      800
# 51711      800
# 51712    1,500
# 51715    2,500
# 51716    1,500
# Name: cost, Length: 43499, dtype: object

# %%
zomato2['cost']=zomato2['cost'].astype(str)

# %%
zomato2['cost']
# Out:
# 0          800
# 1          800
# 2          800
# 3          300
# 4          600
#          ...
# 51709      800
# 51711      800
# 51712    1,500
# 51715    2,500
# 51716    1,500
# Name: cost, Length: 43499, dtype: object

# %%
lambda x:x.replace(',','.')
# Out:
# <function __main__.<lambda>(x)>

# %%
zomato2['cost']=zomato2['cost'].apply(lambda x:x.replace(',','.'))

# %%
zomato2['cost']
# Out:
# 0          800
# 1          800
# 2          800
# 3          300
# 4          600
#          ...
# 51709      800
# 51711      800
# 51712    1.500
# 51715    2.500
# 51716    1.500
# Name: cost, Length: 43499, dtype: object

# %%
zomato2['cost']=zomato2['cost'].astype(float)

# %%
zomato2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 43499 entries, 0 to 51716
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   address          43499 non-null  object
#  1   name             43499 non-null  object
#  2   online_order     43499 non-null  object
#  3   book_table       43499 non-null  object
#  4   rate             43499 non-null  object
#  5   votes            43499 non-null  int64
#  6   location         43499 non-null  object
#  7   rest_type        43499 non-null  object
#  8   cuisines         43499 non-null  object
#  9   cost             43499 non-null  float64
#  10  reviews_list     43499 non-null  object
#  11  menu_item        43499 non-null  object
#  12  city             43499 non-null  object
#  13  listed_in(city)  43499 non-null  object
# dtypes: float64(1), int64(1), object(12)
# memory usage: 5.0+ MB

# %%
zomato2.columns
# Out:
# Index(['address', 'name', 'online_order', 'book_table', 'rate', 'votes',
#        'location', 'rest_type', 'cuisines', 'cost', 'reviews_list',
#        'menu_item', 'city', 'listed_in(city)'],
#       dtype='object')

# %%
zomato2['rate']
# Out:
# 0         4.1/5
# 1         4.1/5
# 2         3.8/5
# 3         3.7/5
# 4         3.8/5
#           ...
# 51709    3.7 /5
# 51711    2.5 /5
# 51712    3.6 /5
# 51715    4.3 /5
# 51716    3.4 /5
# Name: rate, Length: 43499, dtype: object

# %%
type(zomato2['rate'])
# Out:
# pandas.core.series.Series

# %%
zomato2['rate'].unique()
# Out:
# array(['4.1/5', '3.8/5', '3.7/5', '3.6/5', '4.6/5', '4.0/5', '4.2/5',
#        '3.9/5', '3.1/5', '3.0/5', '3.2/5', '3.3/5', '2.8/5', '4.4/5',
#        '4.3/5', 'NEW', '2.9/5', '3.5/5', '2.6/5', '3.8 /5', '3.4/5',
#        '4.5/5', '2.5/5', '2.7/5', '4.7/5', '2.4/5', '2.2/5', '2.3/5',
#        '3.4 /5', '-', '3.6 /5', '4.8/5', '3.9 /5', '4.2 /5', '4.0 /5',
#        '4.1 /5', '3.7 /5', '3.1 /5', '2.9 /5', '3.3 /5', '2.8 /5',
#        '3.5 /5', '2.7 /5', '2.5 /5', '3.2 /5', '2.6 /5', '4.5 /5',
#        '4.3 /5', '4.4 /5', '4.9/5', '2.1/5', '2.0/5', '1.8/5', '4.6 /5',
#        '4.9 /5', '3.0 /5', '4.8 /5', '2.3 /5', '4.7 /5', '2.4 /5',
#        '2.1 /5', '2.2 /5', '2.0 /5', '1.8 /5'], dtype=object)

# %%
zomato3=zomato2.loc[zomato2['rate']!='NEW']

# %%
zomato3
# Out:
#                                                  address  \
# 0      942, 21st Main Road, 2nd Stage, Banashankari, ...
# 1      2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...
# 2      1112, Next to KIMS Medical College, 17th Cross...
# 3      1st Floor, Annakuteera, 3rd Stage, Banashankar...
# 4      10, 3rd Floor, Lakshmi Associates, Gandhi Baza...
# ...                                                  ...
# 51709  136, SAP Labs India, KIADB Export Promotion In...
# 51711  139/C1, Next To GR Tech Park, Pattandur Agraha...
# 51712  Four Points by Sheraton Bengaluru, 43/3, White...
# 51715  Sheraton Grand Bengaluru Whitefield Hotel & Co...
# 51716  ITPL Main Road, KIADB Export Promotion Industr...
#
#                                                     name online_order  \
# 0                                                  Jalsa          Yes
# 1                                         Spice Elephant          Yes
# ...

# %%
zomato4=zomato3.loc[zomato2['rate']!='-']

# %%
zomato4
# Out:
#                                                  address  \
# 0      942, 21st Main Road, 2nd Stage, Banashankari, ...
# 1      2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...
# 2      1112, Next to KIMS Medical College, 17th Cross...
# 3      1st Floor, Annakuteera, 3rd Stage, Banashankar...
# 4      10, 3rd Floor, Lakshmi Associates, Gandhi Baza...
# ...                                                  ...
# 51709  136, SAP Labs India, KIADB Export Promotion In...
# 51711  139/C1, Next To GR Tech Park, Pattandur Agraha...
# 51712  Four Points by Sheraton Bengaluru, 43/3, White...
# 51715  Sheraton Grand Bengaluru Whitefield Hotel & Co...
# 51716  ITPL Main Road, KIADB Export Promotion Industr...
#
#                                                     name online_order  \
# 0                                                  Jalsa          Yes
# 1                                         Spice Elephant          Yes
# ...

# %%
zomato4.shape
# Out:
# (41237, 14)

# %%
zomato4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 41237 entries, 0 to 51716
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   address       41237 non-null  object
#  1   name          41237 non-null  object
#  2   online_order  41237 non-null  object
#  3   book_table    41237 non-null  object
#  4   rate          41237 non-null  object
#  5   votes         41237 non-null  int64
#  6   location      41237 non-null  object
#  7   rest_type     41237 non-null  object
#  8   cuisines      41237 non-null  object
#  9   cost          41237 non-null  float64
#  10  reviews_list  41237 non-null  object
#  11  menu_item     41237 non-null  object
#  12  type          41237 non-null  object
#  13  city          41237 non-null  object
# dtypes: float64(1), int64(1), object(12)
# memory usage: 4.7+ MB

# %%
zomato4['rate'].unique()
# Out:
# array(['4.1/5', '3.8/5', '3.7/5', '3.6/5', '4.6/5', '4.0/5', '4.2/5',
#        '3.9/5', '3.1/5', '3.0/5', '3.2/5', '3.3/5', '2.8/5', '4.4/5',
#        '4.3/5', '2.9/5', '3.5/5', '2.6/5', '3.8 /5', '3.4/5', '4.5/5',
#        '2.5/5', '2.7/5', '4.7/5', '2.4/5', '2.2/5', '2.3/5', '3.4 /5',
#        '3.6 /5', '4.8/5', '3.9 /5', '4.2 /5', '4.0 /5', '4.1 /5',
#        '3.7 /5', '3.1 /5', '2.9 /5', '3.3 /5', '2.8 /5', '3.5 /5',
#        '2.7 /5', '2.5 /5', '3.2 /5', '2.6 /5', '4.5 /5', '4.3 /5',
#        '4.4 /5', '4.9/5', '2.1/5', '2.0/5', '1.8/5', '4.6 /5', '4.9 /5',
#        '3.0 /5', '4.8 /5', '2.3 /5', '4.7 /5', '2.4 /5', '2.1 /5',
#        '2.2 /5', '2.0 /5', '1.8 /5'], dtype=object)

# %%
lambda x:x.replace('/5','') if type(x)==np.str else x
# Out:
# <function __main__.<lambda>(x)>

# %%
remove_slash=lambda x:x.replace('/5','') if type(x)==np.str else x

# %%
remove_slash
# Out:
# <function __main__.<lambda>(x)>

# %%
'   hello   '.rstrip()
# Out:
# '   hello'

# %%
'   hello   '.lstrip()
# Out:
# 'hello   '

# %%
'   hello   '.strip()
# Out:
# 'hello'

# %%
zomato4['rate']=zomato4['rate'].apply(remove_slash).str.strip().astype('float')
# Out:
# C:\Users\ADMIN\AppData\Local\Temp/ipykernel_8088/241488642.py:1: DeprecationWarning: `np.str` is a deprecated alias for the builtin `str`. To silence this warning, use `str` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.str_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   remove_slash=lambda x:x.replace('/5','') if type(x)==np.str else x
# C:\Users\ADMIN\AppData\Local\Temp/ipykernel_8088/1202063695.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   zomato4['rate']=zomato4['rate'].apply(remove_slash).str.strip().astype('float')

# %%
zomato4.columns
# Out:
# Index(['address', 'name', 'online_order', 'book_table', 'rate', 'votes',
#        'location', 'rest_type', 'cuisines', 'cost', 'reviews_list',
#        'menu_item', 'type', 'city'],
#       dtype='object')

# %%
zomato4['rate'].unique()
# Out:
# array([4.1, 3.8, 3.7, 3.6, 4.6, 4. , 4.2, 3.9, 3.1, 3. , 3.2, 3.3, 2.8,
#        4.4, 4.3, 2.9, 3.5, 2.6, 3.4, 4.5, 2.5, 2.7, 4.7, 2.4, 2.2, 2.3,
#        4.8, 4.9, 2.1, 2. , 1.8])

# %%
zomato4.head()
# Out:
#                                              address                   name  \
# 0  942, 21st Main Road, 2nd Stage, Banashankari, ...                  Jalsa
# 1  2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...         Spice Elephant
# 2  1112, Next to KIMS Medical College, 17th Cross...        San Churro Cafe
# 3  1st Floor, Annakuteera, 3rd Stage, Banashankar...  Addhuri Udupi Bhojana
# 4  10, 3rd Floor, Lakshmi Associates, Gandhi Baza...          Grand Village
#
#   online_order book_table  rate  votes      location            rest_type  \
# 0          Yes        Yes   4.1    775  Banashankari        Casual Dining
# 1          Yes         No   4.1    787  Banashankari        Casual Dining
# 2          Yes         No   3.8    918  Banashankari  Cafe, Casual Dining
# 3           No         No   3.7     88  Banashankari          Quick Bites
# 4           No         No   3.8    166  Basavanagudi        Casual Dining
#
#                          cuisines   cost  \
# ...

# %%
zomato4['name']
# Out:
# 0                                                    Jalsa
# 1                                           Spice Elephant
# 2                                          San Churro Cafe
# 3                                    Addhuri Udupi Bhojana
# 4                                            Grand Village
#                                ...
# 51709                           The Farm House Bar n Grill
# 51711                                              Bhagini
# 51712    Best Brews - Four Points by Sheraton Bengaluru...
# 51715    Chime - Sheraton Grand Bengaluru Whitefield Ho...
# 51716                         The Nest - The Den Bengaluru
# Name: name, Length: 41237, dtype: object

# %%
zomato4['name']=zomato4['name'].apply(lambda x:x.title())
# Out:
# C:\Users\ADMIN\AppData\Local\Temp/ipykernel_8088/890347988.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   zomato4['name']=zomato4['name'].apply(lambda x:x.title())

# %%
zomato4['name']
# Out:
# 0                                                    Jalsa
# 1                                           Spice Elephant
# 2                                          San Churro Cafe
# 3                                    Addhuri Udupi Bhojana
# 4                                            Grand Village
#                                ...
# 51709                           The Farm House Bar N Grill
# 51711                                              Bhagini
# 51712    Best Brews - Four Points By Sheraton Bengaluru...
# 51715    Chime - Sheraton Grand Bengaluru Whitefield Ho...
# 51716                         The Nest - The Den Bengaluru
# Name: name, Length: 41237, dtype: object

# %%
zomato4
# Out:
#                                                  address  \
# 0      942, 21st Main Road, 2nd Stage, Banashankari, ...
# 1      2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...
# 2      1112, Next to KIMS Medical College, 17th Cross...
# 3      1st Floor, Annakuteera, 3rd Stage, Banashankar...
# 4      10, 3rd Floor, Lakshmi Associates, Gandhi Baza...
# ...                                                  ...
# 51709  136, SAP Labs India, KIADB Export Promotion In...
# 51711  139/C1, Next To GR Tech Park, Pattandur Agraha...
# 51712  Four Points by Sheraton Bengaluru, 43/3, White...
# 51715  Sheraton Grand Bengaluru Whitefield Hotel & Co...
# 51716  ITPL Main Road, KIADB Export Promotion Industr...
#
#                                                     name online_order  \
# 0                                                  Jalsa          Yes
# 1                                         Spice Elephant          Yes
# ...

# %%
zomato4['online_order'].replace(('Yes','No'),(True,False),inplace=True)
# Out:
# C:\Users\ADMIN\Raviraj\anaconda3\lib\site-packages\pandas\core\generic.py:6619: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return self._update_inplace(result)

# %%
zomato4.head()
# Out:
#                                              address                   name  \
# 0  942, 21st Main Road, 2nd Stage, Banashankari, ...                  Jalsa
# 1  2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...         Spice Elephant
# 2  1112, Next to KIMS Medical College, 17th Cross...        San Churro Cafe
# 3  1st Floor, Annakuteera, 3rd Stage, Banashankar...  Addhuri Udupi Bhojana
# 4  10, 3rd Floor, Lakshmi Associates, Gandhi Baza...          Grand Village
#
#    online_order book_table  rate  votes      location            rest_type  \
# 0          True        Yes   4.1    775  Banashankari        Casual Dining
# 1          True         No   4.1    787  Banashankari        Casual Dining
# 2          True         No   3.8    918  Banashankari  Cafe, Casual Dining
# 3         False         No   3.7     88  Banashankari          Quick Bites
# 4         False         No   3.8    166  Basavanagudi        Casual Dining
#
#                          cuisines   cost  \
# ...

# %%
zomato4['book_table'].replace(('Yes','No'),(True,False),inplace=True)
# Out:
# C:\Users\ADMIN\Raviraj\anaconda3\lib\site-packages\pandas\core\generic.py:6619: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return self._update_inplace(result)

# %%
zomato4.head()
# Out:
#                                              address                   name  \
# 0  942, 21st Main Road, 2nd Stage, Banashankari, ...                  Jalsa
# 1  2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...         Spice Elephant
# 2  1112, Next to KIMS Medical College, 17th Cross...        San Churro Cafe
# 3  1st Floor, Annakuteera, 3rd Stage, Banashankar...  Addhuri Udupi Bhojana
# 4  10, 3rd Floor, Lakshmi Associates, Gandhi Baza...          Grand Village
#
#    online_order  book_table  rate  votes      location            rest_type  \
# 0          True        True   4.1    775  Banashankari        Casual Dining
# 1          True       False   4.1    787  Banashankari        Casual Dining
# 2          True       False   3.8    918  Banashankari  Cafe, Casual Dining
# 3         False       False   3.7     88  Banashankari          Quick Bites
# 4         False       False   3.8    166  Basavanagudi        Casual Dining
#
#                          cuisines   cost  \
# ...

# %%
zomato4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 41237 entries, 0 to 51716
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   address       41237 non-null  object
#  1   name          41237 non-null  object
#  2   online_order  41237 non-null  bool
#  3   book_table    41237 non-null  bool
#  4   rate          41237 non-null  float64
#  5   votes         41237 non-null  int64
#  6   location      41237 non-null  object
#  7   rest_type     41237 non-null  object
#  8   cuisines      41237 non-null  object
#  9   cost          41237 non-null  float64
#  10  reviews_list  41237 non-null  object
#  11  menu_item     41237 non-null  object
#  12  type          41237 non-null  object
#  13  city          41237 non-null  object
# dtypes: bool(2), float64(2), int64(1), object(9)
# memory usage: 4.2+ MB

# %%
zomato4['cost'].unique()
# Out:
# array([800.  , 300.  , 600.  , 700.  , 550.  , 500.  , 450.  , 650.  ,
#        400.  , 900.  , 200.  , 750.  , 150.  , 850.  , 100.  ,   1.2 ,
#        350.  , 250.  , 950.  ,   1.  ,   1.5 ,   1.3 , 199.  ,   1.1 ,
#          1.6 , 230.  , 130.  ,   1.7 ,   1.35,   2.2 ,   1.4 ,   2.  ,
#          1.8 ,   1.9 , 180.  , 330.  ,   2.5 ,   2.1 ,   3.  ,   2.8 ,
#          3.4 ,  50.  ,  40.  ,   1.25,   3.5 ,   4.  ,   2.4 ,   2.6 ,
#          1.45,  70.  ,   3.2 , 240.  ,   6.  ,   1.05,   2.3 ,   4.1 ,
#        120.  ,   5.  ,   3.7 ,   1.65,   2.7 ,   4.5 ,  80.  ])

# %%
zomato4['name'].factorize()
# Out:
# (array([   0,    1,    2, ..., 6532, 6568, 6569], dtype=int64),
#  Index(['Jalsa', 'Spice Elephant', 'San Churro Cafe', 'Addhuri Udupi Bhojana',
#         'Grand Village', 'Timepass Dinner',
#         'Rosewood International Hotel - Bar & Restaurant', 'Onesta',
#         'Penthouse Cafe', 'Smacznego',
#         ...
#         'Food Dig', 'Ishwaryam', 'Hungry Wok', 'Mad Kitchen', 'Polly'S Kitchen',
#         'Calcutta North Indian Meals',
#         'Chime - Sheraton Grand Bengaluru Whitefield Hotel &...',
#         'The Nest - The Den Bengaluru', 'Nawabs Empire', 'Seeya Restaurant'],
#        dtype='object', length=6572))

# %%
zomato5=zomato4['name'].factorize()

# %%
zomato5
# Out:
# (array([   0,    1,    2, ..., 6532, 6568, 6569], dtype=int64),
#  Index(['Jalsa', 'Spice Elephant', 'San Churro Cafe', 'Addhuri Udupi Bhojana',
#         'Grand Village', 'Timepass Dinner',
#         'Rosewood International Hotel - Bar & Restaurant', 'Onesta',
#         'Penthouse Cafe', 'Smacznego',
#         ...
#         'Food Dig', 'Ishwaryam', 'Hungry Wok', 'Mad Kitchen', 'Polly'S Kitchen',
#         'Calcutta North Indian Meals',
#         'Chime - Sheraton Grand Bengaluru Whitefield Hotel &...',
#         'The Nest - The Den Bengaluru', 'Nawabs Empire', 'Seeya Restaurant'],
#        dtype='object', length=6572))

# %%
zomato4['name'].factorize()[0]
# Out:
# array([   0,    1,    2, ..., 6532, 6568, 6569], dtype=int64)

# %%
def Encode(zomato):
    for column in zomato.columns[~zomato.columns.isin(['rate','votes','cost'])]:
        zomato[column]=zomato[column].factorize()[0]
    return zomato

# %%
zomato5_encoded=Encode(zomato4.copy())

# %%
zomato5_encoded
# Out:
#        address  name  online_order  book_table  rate  votes  location  \
# 0            0     0             0           0   4.1    775         0
# 1            1     1             0           1   4.1    787         0
# 2            2     2             0           1   3.8    918         0
# 3            3     3             1           1   3.7     88         0
# 4            4     4             1           1   3.8    166         1
# ...        ...   ...           ...         ...   ...    ...       ...
# 51709     3137  2699             1           1   3.7     34        25
# 51711     8791  1716             1           1   2.5     81        25
# 51712     8725  6532             1           1   3.6     27        25
# 51715     8786  6568             1           0   4.3    236        56
# 51716     3444  6569             1           1   3.4     13        56
#
#        rest_type  cuisines   cost  reviews_list  menu_item  type  city
# ...

# %%
zomato5_encoded.columns
# Out:
# Index(['address', 'name', 'online_order', 'book_table', 'rate', 'votes',
#        'location', 'rest_type', 'cuisines', 'cost', 'reviews_list',
#        'menu_item', 'type', 'city'],
#       dtype='object')

# %%
type(zomato5_encoded)
# Out:
# pandas.core.frame.DataFrame

# %%
zomato5_encoded.corr()
# Out:
#                address      name  online_order  book_table      rate  \
# address       1.000000  0.682346      0.165707    0.021447 -0.036195
# name          0.682346  1.000000      0.231616   -0.033718 -0.046936
# online_order  0.165707  0.231616      1.000000   -0.054894 -0.069042
# book_table    0.021447 -0.033718     -0.054894    1.000000 -0.426027
# rate         -0.036195 -0.046936     -0.069042   -0.426027  1.000000
# votes        -0.010738 -0.043871      0.013278   -0.393270  0.435237
# location      0.614626  0.448705      0.048645   -0.032781  0.030363
# rest_type     0.030634  0.036212      0.136741   -0.226763  0.196933
# cuisines      0.238421  0.301793      0.049921   -0.225396  0.189624
# cost          0.003227 -0.084328     -0.180782    0.266651 -0.115346
# reviews_list  0.512074  0.339130      0.051440   -0.132809  0.159661
# menu_item     0.058929 -0.031798     -0.362114    0.040496  0.054942
# type          0.094137  0.116000      0.239236   -0.114302  0.034038
# ...

# %%
plt.figure(figsize=(18,8))
sns.heatmap(zomato5_encoded.corr(),annot=True,cmap='Set1')
# Out:
# <AxesSubplot:>

# %%
sns.countplot(zomato4['online_order'])
# Out:
# C:\Users\ADMIN\Raviraj\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='online_order', ylabel='count'>

# %%
zomato4=zomato3.loc[zomato3['rate']!='-']

# %%
zomato4['rate']=zomato4['rate'].apply(remove_slash).str.strip().astype('float')
# Out:
# C:\Users\ADMIN\AppData\Local\Temp/ipykernel_8088/241488642.py:1: DeprecationWarning: `np.str` is a deprecated alias for the builtin `str`. To silence this warning, use `str` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.str_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   remove_slash=lambda x:x.replace('/5','') if type(x)==np.str else x
# C:\Users\ADMIN\AppData\Local\Temp/ipykernel_8088/1202063695.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   zomato4['rate']=zomato4['rate'].apply(remove_slash).str.strip().astype('float')

# %%
zomato4['name']=zomato4['name'].apply(lambda x:x.title())
# Out:
# C:\Users\ADMIN\AppData\Local\Temp/ipykernel_8088/890347988.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   zomato4['name']=zomato4['name'].apply(lambda x:x.title())

# %%
zomato4['online_order'].replace(('Yes','No'),(True,False),inplace=True)
# Out:
# C:\Users\ADMIN\Raviraj\anaconda3\lib\site-packages\pandas\core\generic.py:6619: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return self._update_inplace(result)

# %%
zomato4['book_table'].replace(('Yes','No'),(True,False),inplace=True)

# %%
zomato4
# Out:
#                                                  address  \
# 0      942, 21st Main Road, 2nd Stage, Banashankari, ...
# 1      2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...
# 2      1112, Next to KIMS Medical College, 17th Cross...
# 3      1st Floor, Annakuteera, 3rd Stage, Banashankar...
# 4      10, 3rd Floor, Lakshmi Associates, Gandhi Baza...
# ...                                                  ...
# 51709  136, SAP Labs India, KIADB Export Promotion In...
# 51711  139/C1, Next To GR Tech Park, Pattandur Agraha...
# 51712  Four Points by Sheraton Bengaluru, 43/3, White...
# 51715  Sheraton Grand Bengaluru Whitefield Hotel & Co...
# 51716  ITPL Main Road, KIADB Export Promotion Industr...
#
#                                                     name  online_order  \
# 0                                                  Jalsa          True
# 1                                         Spice Elephant          True
# ...

# %%
sns.countplot(zomato4['online_order'])
# Out:
# C:\Users\ADMIN\Raviraj\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='online_order', ylabel='count'>

# %%
sns.countplot(zomato4['online_order'])  ##get current figure(gcf)
fig=plt.gcf()
fig.set_size_inches(8,8)
plt.title("Restaurants delivering online on not")
# Out:
# C:\Users\ADMIN\Raviraj\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Restaurants delivering online on not')

# %%
sns.countplot(zomato4['book_table'])  ##get current figure(gcf)
fig=plt.gcf()
fig.set_size_inches(8,8)
plt.title("Restaurants delivering online on not")
# Out:
# C:\Users\ADMIN\Raviraj\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Restaurants delivering online on not')

# %%
pd.crosstab(zomato4['rate'],zomato4['book_table'])
# Out:
# book_table  False  True
# rate
# 1.8             5     0
# 2.0            11     0
# 2.1            24     0
# 2.2            13    13
# 2.3            51     0
# 2.4            66     0
# 2.5            98     2
# 2.6           245     4
# 2.7           299     4
# 2.8           574     6
# 2.9           792     9
# 3.0           981     9
# 3.1          1540    10
# 3.2          1821    23
# 3.3          2267     5
# 3.4          2428    16
# 3.5          2677    86
# 3.6          3214    72
# 3.7          3589   218
# 3.8          3465   351
# 3.9          3398   556
# 4.0          2459   685
# 4.1          1937   988
# 4.2          1204   950
# 4.3           923   759
# 4.4           369   777
# 4.5           233   423
# 4.6           167   133
# 4.7            50   117
# 4.8            23    43
# 4.9            15    40

# %%
plt.rcParams['figure.figsize']=(15,10)
Y=pd.crosstab(zomato4['rate'],zomato4['book_table'])
Y.div(Y.sum(1).astype(float),axis=0).plot(kind='bar',stacked=True,color=['red','yellow'])
plt.title("Table booking Vs normal rate")
plt.legend(loc="upper right")

# %%
zomato4['city']
# Out:
# 0        Banashankari
# 1        Banashankari
# 2        Banashankari
# 3        Banashankari
# 4        Banashankari
#              ...
# 51709      Whitefield
# 51711      Whitefield
# 51712      Whitefield
# 51715      Whitefield
# 51716      Whitefield
# Name: city, Length: 41237, dtype: object

# %%
zomato4
# Out:
#                                                  address  \
# 0      942, 21st Main Road, 2nd Stage, Banashankari, ...
# 1      2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...
# 2      1112, Next to KIMS Medical College, 17th Cross...
# 3      1st Floor, Annakuteera, 3rd Stage, Banashankar...
# 4      10, 3rd Floor, Lakshmi Associates, Gandhi Baza...
# ...                                                  ...
# 51709  136, SAP Labs India, KIADB Export Promotion In...
# 51711  139/C1, Next To GR Tech Park, Pattandur Agraha...
# 51712  Four Points by Sheraton Bengaluru, 43/3, White...
# 51715  Sheraton Grand Bengaluru Whitefield Hotel & Co...
# 51716  ITPL Main Road, KIADB Export Promotion Industr...
#
#                                                     name  online_order  \
# 0                                                  Jalsa          True
# 1                                         Spice Elephant          True
# ...

# %%
sns.countplot(zomato4['city'])
sns.countplot(zomato4['city']).set_xticklabels(sns.countplot(zomato4['city']).get_xticklabels(),
                                              rotation=90,ha="right")
fig=plt.gcf()
fig.set_size_inches(10,10)
plt.title("Location wise count for the restaurants")
# Out:
# C:\Users\ADMIN\Raviraj\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\ADMIN\Raviraj\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\ADMIN\Raviraj\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
# ...

# %%
zomato4
# Out:
#                                                  address  \
# 0      942, 21st Main Road, 2nd Stage, Banashankari, ...
# 1      2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...
# 2      1112, Next to KIMS Medical College, 17th Cross...
# 3      1st Floor, Annakuteera, 3rd Stage, Banashankar...
# 4      10, 3rd Floor, Lakshmi Associates, Gandhi Baza...
# ...                                                  ...
# 51709  136, SAP Labs India, KIADB Export Promotion In...
# 51711  139/C1, Next To GR Tech Park, Pattandur Agraha...
# 51712  Four Points by Sheraton Bengaluru, 43/3, White...
# 51715  Sheraton Grand Bengaluru Whitefield Hotel & Co...
# 51716  ITPL Main Road, KIADB Export Promotion Industr...
#
#                                                     name  online_order  \
# 0                                                  Jalsa          True
# 1                                         Spice Elephant          True
# ...

# %%
##Session 25_ 15 April 2022

# %%
pd.crosstab(zomato4['rate'],zomato4['city'])
# Out:
# city  BTM  Banashankari  Bannerghatta Road  Basavanagudi  Bellandur  \
# rate
# 1.8     0             0                  0             0          0
# 2.0     0             0                  0             0          0
# 2.1     0             0                  0             0          2
# 2.2     2             0                  2             0          1
# 2.3     4             0                  3             0          4
# 2.4     2             0                  5             0          1
# 2.5     6             3                  2             3          1
# 2.6    19             4                 12             7          9
# 2.7    20             6                 16            11          4
# 2.8    28             8                 15            14         15
# 2.9    40             9                 44            13         41
# 3.0    55            22                 38            25         41
# 3.1    94            24                 65            30         46
# ...

# %%
city_rate=pd.crosstab(zomato4['rate'],zomato4['city'])
plt.rcParams['figure.figsize']=(15,10)
city_rate.plot(kind="bar",stacked=True)
plt.title("Location wise rating",fontsize=18,fontweight='bold')
plt.ylabel("Location",fontsize=12,fontweight='bold')
plt.xlabel("Rating",fontsize=12,fontweight='bold')
plt.xticks(fontsize=12,fontweight='bold')
plt.yticks(fontsize=12,fontweight='bold')

plt.legend()

# %%
type(city_rate)
# Out:
# pandas.core.frame.DataFrame

# %%
zomato4
# Out:
#                                                  address  \
# 0      942, 21st Main Road, 2nd Stage, Banashankari, ...
# 1      2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...
# 2      1112, Next to KIMS Medical College, 17th Cross...
# 3      1st Floor, Annakuteera, 3rd Stage, Banashankar...
# 4      10, 3rd Floor, Lakshmi Associates, Gandhi Baza...
# ...                                                  ...
# 51709  136, SAP Labs India, KIADB Export Promotion In...
# 51711  139/C1, Next To GR Tech Park, Pattandur Agraha...
# 51712  Four Points by Sheraton Bengaluru, 43/3, White...
# 51715  Sheraton Grand Bengaluru Whitefield Hotel & Co...
# 51716  ITPL Main Road, KIADB Export Promotion Industr...
#
#                                                     name  online_order  \
# 0                                                  Jalsa          True
# 1                                         Spice Elephant          True
# ...

# %%
sns.countplot(zomato4['rest_type'])
sns.countplot(zomato4['rest_type']).set_xticklabels(sns.countplot(zomato4['rest_type']).get_xticklabels(),
                                              rotation=90,ha="right")
fig=plt.gcf()
fig.set_size_inches(13,13)
plt.title("Location wise count for the restaurants")
# Out:
# C:\Users\ADMIN\Raviraj\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\ADMIN\Raviraj\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\ADMIN\Raviraj\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
# ...

# %%
loc_plt=pd.crosstab(zomato4['rate'],zomato4['rest_type'])
loc_plt.plot(kind='bar',stacked=True);
plt.title('Rest type - Rating',fontsize=15,fontweight='bold')
plt.ylabel('Rest type',fontsize=10,fontweight='bold')
plt.xlabel('Rating',fontsize=10,fontweight='bold')
plt.xticks(fontsize=10,fontweight='bold')
plt.yticks(fontsize=10,fontweight='bold');
plt.legend().remove();

# %%
sns.countplot(zomato4['type'])
sns.countplot(zomato4['type']).set_xticklabels(sns.countplot(zomato4['type']).get_xticklabels(), rotation=90, ha="right")
fig = plt.gcf()
fig.set_size_inches(15,15)
plt.title('Type of Service')
# Out:
# C:\Users\ADMIN\Raviraj\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\ADMIN\Raviraj\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\ADMIN\Raviraj\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
# ...

# %%
type_plt=pd.crosstab(zomato4['rate'],zomato4['type'])
type_plt.plot(kind='bar',stacked=True);
plt.title('Type - Rating',fontsize=15,fontweight='bold')
plt.ylabel('Type',fontsize=10,fontweight='bold')
plt.xlabel('Rating',fontsize=10,fontweight='bold')
plt.xticks(fontsize=10,fontweight='bold')
plt.yticks(fontsize=10,fontweight='bold');

# %%
sns.countplot(zomato4['cost'])
sns.countplot(zomato4['cost']).set_xticklabels(sns.countplot(zomato4['cost']).get_xticklabels(), rotation=90, ha="right")
fig = plt.gcf()
fig.set_size_inches(15,15)
plt.title('Cost of Restuarant')
# Out:
# C:\Users\ADMIN\Raviraj\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\ADMIN\Raviraj\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\ADMIN\Raviraj\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
# ...

# %%
fig = plt.figure(figsize=(20,7))
loc = sns.countplot(x="location",data=zomato4, palette = "Set1")
loc.set_xticklabels(loc.get_xticklabels(), rotation=90, ha="right")
plt.ylabel("Frequency",size=15)
plt.xlabel("Location",size=18)
loc
plt.title('NO. of restaurants in a Location',size = 20,pad=20)
# Out:
# Text(0.5, 1.0, 'NO. of restaurants in a Location')

# %%
fig = plt.figure(figsize=(17,5))
rest = sns.countplot(x="rest_type",data=zomato4, palette = "Set1")
rest.set_xticklabels(rest.get_xticklabels(), rotation=90, ha="right")
plt.ylabel("Frequency",size=15)
plt.xlabel("Restaurant type",size=15)
rest 
plt.title('Restaurant types',fontsize = 20 ,pad=20)
# Out:
# Text(0.5, 1.0, 'Restaurant types')

# %%
plt.figure(figsize=(15,7))
chains=zomato4['name'].value_counts()[:20]
sns.barplot(x=chains,y=chains.index,palette='Set1')
plt.title("Most famous restaurant chains in Bangaluru",size=20,pad=20)
plt.xlabel("Number of outlets",size=15)
# Out:
# Text(0.5, 0, 'Number of outlets')
